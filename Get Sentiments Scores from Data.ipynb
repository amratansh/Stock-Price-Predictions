# %%
import pysentiment
import pandas
from IPython.display import clear_output
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA
# Out:
# C:\Users\simon\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %%
df=pandas.read_excel("Analyst_reports1.xls",sheet_name="Sheet1")

# %%
df["Combined"]=df["Headline"]+df["First Paragraph"]+df["Last Paragraph"]

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=655, step=1),
#  Index(['Company', 'Headline', 'Author', 'Date', 'First Paragraph',
#         'Last Paragraph', 'Combined'],
#        dtype='object')]

# %%
df["Headline"][0:10]
# Out:
# 0    Cisco Posts Another Record Quarter With Growth...
# 1    Cisco Reports Record Quarterly Revenue and Pro...
# 2    Cisco's focus on software and services prepare...
# 3    Acquisition of Duo Security Fits With Cisco's ...
# 4    Cisco Readies for Cloud Networking Era With So...
# 5    Cisco Continues to Shift Toward Recurring Subs...
# 6    Cisco Announces Solid Results and Aggressive S...
# 7    Cisco continues to transition to a software-de...
# 8                           Cisco Systems Under Review
# 9    Cisco's 1Q Results Are in Line; Top Line Shoul...
# Name: Headline, dtype: object

# %%
def get_Finance_score(row,LM):
    
    return pandas.Series(LM.get_score(LM.tokenize(text=row)))["Polarity"]

# %%
lm=pysentiment.LM()

lm.get_score(lm.tokenize(text=df["Headline"][0])).values()

# %%
def get_General_score(row):
    sid=SIA()
    score=sid.polarity_scores(row)
    
    return score["compound"]

# %%
df["Headline"][0:100].apply(get_General_score)

# %%
nltk.download("vader_lexicon")

# %%
pandas.DataFrame(df["Company"],df["Date"]).to_dict()

# %%
dataframe=pandas.DataFrame([df["Company"],df["Date"],df["Author"]])

LM=pysentiment.LM()


for COL in  ["Headline",'First Paragraph','Last Paragraph',"Combined"]:
    dataframe=dataframe.append(
        pandas.Series(df[COL].apply(get_Finance_score,args=([LM])),name="Finance "+COL)
    )
    
    dataframe=dataframe.append(
        pandas.Series(df[COL].apply(get_General_score),name="General "+COL)
    )
    
dataframe.T
# Out:
#                      Company                 Date               Author  \
# 0                      Cisco          11/14/2018             Mark Cash
# 1                      Cisco          08/15/2018             Mark Cash
# 2                      Cisco          07/17/2018             Mark Cash
# 3                      Cisco          08/02/2018             Mark Cash
# 4                      Cisco          07/17/2018             Mark Cash
# 5                      Cisco          05/16/2018         Brian Colello
# 6                      Cisco          02/14/2018         Brian Colello
# 7                      Cisco          02/14/2018         Brian Colello
# 8                      Cisco          02/12/2018         Brian Colello
# 9                      Cisco          11/15/2017       Ilya Kundozerov
# 10                     Cisco          06/09/2017       Ilya Kundozerov
# 11                     Cisco          11/02/2017          Michael Wong
# 12                     Cisco          10/23/2017       Ilya Kundozerov
# 13                     Cisco          09/27/2017          Michael Wong
# 14                     Cisco          08/21/2017       Ilya Kundozerov
# 15                     Cisco          08/16/2017       Ilya Kundozerov
# 16                     Cisco  2017-06-28 00:00:00      Ilya Kundozerov
# 17                     Cisco          06/09/2017       Ilya Kundozerov
# 18                     Cisco          05/18/2017       Ilya Kundozerov
# 19                     Cisco          05/02/2017       Ilya Kundozerov
# 20                     Cisco          04/26/2017          Michael Wong
# 21                     Cisco          04/07/2017          Michael Wong
# 24          0.999999             0.34                     0.5
# 25                 0           0.5719               -0.714286
# 26         -0.999999                0                0.333333
# 27                 0            -0.25                       0
# 28                 0                0                0.999999
# 29          0.999999           0.6249                0.666667
# ..               ...              ...                     ...
# 625                1           0.7184                       1
# 626                1           0.8807                       0
# 627         0.999999           0.5267                       1
# 628                0           0.7096                       0
# 629                0           0.6124                       0
# 630        -0.999999             0.25                       0
# 631                0             0.25                       0
# 632        -0.999999           0.4019                0.999999
# 633                0           0.7845                     0.5
# 634                0           0.1531                     0.5
# 635         0.999999           0.3818               -0.999999
# 636                0                0                       0
# 637        -0.999999                0                       0
# 638                0          -0.3724                       0
# 639        -0.999999           0.4588                       0
# 640         0.999999           0.3818               -0.999999
# 641         0.999999           0.3818               -0.999999
# 642         0.999999           0.5106                0.999999
# 643         0.999999           0.3818               -0.999999
# 644                0                0                    -0.2
# 645         0.999999           0.4939                       0
# 646                0           0.4215               -0.999999
# 647         0.999999                0                       0
# 648                0          -0.2263                       0
# 649                0                0                       0
# 650                0           0.1531                0.428571
# 651         0.999999           0.3818               -0.999999
# 652         0.999999          -0.1613                0.636364
# 653                0           0.1531                       0
# 654                0           0.6597                       1
#
#     General First Paragraph Finance Last Paragraph General Last Paragraph  \
# 0                    0.9882                    0.2                 0.9657
# 1                    0.9545               0.999999                 0.9313
# 2                    0.5106                      0                 0.9325
# 3                    0.8658                      0                 0.8481
# 4                    0.9428              -0.999999                 0.5106
# 5                    0.9545              -0.999999                -0.5187
# 6                    0.9455                      0                 0.6997
# 7                    0.7184               0.999999                 0.8625
# 8                    0.5719                      0                      0
# 9                    0.9857              -0.428571                 0.5499
# 10                   0.8885               0.333333                 0.2263
# 11                   0.9201                    0.5                 0.8519
# 12                   0.6808              -0.333333                  0.926
# 13                   0.8955                      0                 0.7351
# 14                   0.7804                      1                 0.9493
# 15                   0.6478                      0                 0.9418
# 16                   0.8985                      0                 0.6908
# 17                   0.9393                      1                 0.9393
# 18                   0.8979              -0.333333                 0.9194
# 19                   0.8625                      0                 0.9081
# 20                   0.6956                     -1                 0.7783
# 21                   0.7184                      0                 0.7184
# 22                   0.9769              -0.333333                 0.9524
# 23                   0.8885               0.333333                 0.2263
# 24                   0.6597              -0.999999                 0.9186
# 25                   0.2023              -0.555555                -0.5091
# 26                   0.9567                   -0.4                 0.9881
# 27                  -0.1027              -0.333333                 0.9587
# 28                   0.7506                   -0.5                 0.8885
# 29                   0.9943              -0.333333                 0.6249
# ..                      ...                    ...                    ...
# 625                   0.926                      0                 0.9062
# 626                  0.9584               0.333333                 0.6648
# 627                   0.926                      0                 0.9062
# 628                  0.9423               0.999999                 0.6808
# 629                  0.9833                      1                 0.9825
# 630                  0.8591                      0                 0.8225
# 631                   0.891               0.333333                 0.9423
# 632                  0.9903                      0                 0.6705
# 633                  0.9741                      0                 0.8885
# 634                  0.9774                      1                  0.872
# 635                  0.2023                      0                 0.4767
# 636                  0.5719                      0                      0
# 637                  0.8338              -0.999999                 0.8462
# 638                 -0.3612              -0.999999                 0.6106
# 639                  0.2023                   -0.5                 0.7698
# 640                  0.2023                      0                 0.4767
# 641                  0.2023                      0                 0.4767
# 642                  0.9868                      0                 0.5325
# 643                    0.34                      0                 0.4767
# 644                  0.7964                      1                 0.8225
# 645                    0.91                      1                 0.9707
# 646                    0.91                    0.2                  0.974
# 647                  0.7783              -0.999999                 0.9657
# 648                   0.765              -0.333333                 0.8316
# 649                  0.5719                      0                      0
# 650                  0.9911               0.333333                 0.8481
# 651                    0.34               0.999999                 0.8176
# 652                  0.9923               0.333333                 0.7003
# 653                  0.9657               0.333333                  0.891
# 654                  0.8399                      1                 0.9186
#
#     Finance Combined General Combined
# 0                0.5           0.9956
# 1           0.999999           0.9859
# 2          -0.999999           0.9485
# 3           0.333333           0.9753
# 4          -0.333333           0.9623
# 5                0.5            0.705
# 6                  0           0.9748
# 7                  1           0.9393
# 8                  0           0.5719
# 9          -0.384615           0.9864
# 10          0.333333           0.9081
# 11               0.2           0.9805
# 12         -0.142857            0.946
# 13          0.333333           0.9686
# 14          0.666667           0.9736
# 15         -0.333333           0.9434
# 16          0.333333           0.9564
# 17                 1           0.9837
# 18             -0.25           0.9603
# 19               0.5           0.9729
# 20                -1            0.962
# 21                 0           0.9001
# 22         -0.230769           0.9917
# 23          0.333333           0.9081
# 24          0.333333           0.9628
# 25            -0.625          -0.3051
# 26              -0.1           0.9947
# 27             -0.25           0.9489
# 28              -0.2           0.9509
# 29               0.4           0.9957
# ..               ...              ...
# 625                1           0.9846
# 626              0.5           0.9535
# 627                1           0.9821
# 628         0.333333           0.9786
# 629         0.666667           0.9959
# 630        -0.999999            0.959
# 631              0.2           0.9808
# 632                0           0.9934
# 633              0.5           0.9913
# 634         0.666667           0.9886
# 635                0           0.7579
# 636                0           0.5719
# 637        -0.333333           0.9595
# 638        -0.999999          -0.0176
# 639             -0.5           0.8878
# 640                0           0.7579
# 641                0           0.7579
# 642              0.5           0.9895
# 643                0           0.7964
# 644             0.25           0.9403
# 645              0.6           0.9931
# 646         0.142857           0.9821
# 647                0           0.9803
# 648        -0.333333            0.967
# 649                0           0.5719
# 650              0.4           0.9942
# 651         0.333333             0.91
# 652              0.6           0.9936
# 653              0.2           0.9856
# 654                1           0.9785
#
# [655 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(pandas.DataFrame([dataframe.T["Finance Last Paragraph"],dataframe.T["General Last Paragraph"]]).T)

# %%
dataframe

# %%
dataframe.T.to_csv("Sentiments_Final_really.csv",sep=",",index=False)

# %%
{k.strip() for k in sorted(dataframe.T["Author"].unique())}

# %%
x=dataframe.T["Date"]

# %%
def clean(row):
    if type(row)==datetime.datetime:
        return row
    row=datetime.datetime.strptime(row.strip(),"%M/%d/%Y")
    return row

# %%
x.apply(clean)

# %%
import datetime

# %%
x.values

# %%
df["Date"]=df["Date"].apply(clean)

# %%
df[df["Company"]=="Kroger"]

# %%
dataframe.T[dataframe.T["Company"]=="Apple"].T[352].T

# %%
import random

# %%
random.randint(1,575)
# Out:
# 541
